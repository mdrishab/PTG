# %%
import pandas as pd
import glob
from os import path
import os
import fitz
import unicodedata
import re
import spacy
import tqdm
import argilla as rg
import json
import shutil
from pathlib import Path
import boto3

# %%
client = boto3.client(service_name='s3',
                              region_name='ap-south-1',
                              aws_access_key_id='AKIAZP5PPFU6K5W2OJXZ',
                              aws_secret_access_key='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')
response = client.list_objects_v2(
    Bucket="fractionable",
    Prefix=f"golden_dataset/entire_resume")
golden_dataset = []
for res in response['Contents'][1:]:
    #if res['LastModified'] >= last_trained_date:
    res_1 = client.get_object(Bucket='fractionable', Key=res['Key'])
    content = res_1['Body']
    jsonObject = json.loads(content.read())
    golden_dataset.append(jsonObject)
print(len(golden_dataset))
# Out:
# 55

# %%
nlp=spacy.load(r"/home/ptgml/latest_train/entire_resume_20230608-090016/model-best")

# %%
missed_skills=[]

for resumes in golden_dataset:
    doc=nlp1(resumes[0])
    predicted_skills = []
    for ent in doc.ents:
        if ent.label_ == "SKILLS":
            predicted_skills.append(ent.text)
    actual_skills = []
    for ent in resumes[1]['entities']:
        if ent[2] == "SKILLS":
            actual_skills.append(resumes[0][ent[0]:ent[1]]) 
   
    missed_skills.extend(list(set(actual_skills) - set(predicted_skills)))

    #print(doc)

# %%
missed_skills
# Out:
# ['Staffing/Client Onboarding formalities/BGV/access rights management',
#  'Process Management',
#  'Project support',
#  'SharePoint - Document maintenance',
#  'Program project management',
#  'Resource Management',
#  'Different types of Financial Billing/Invoice Validation',
#  'Space utilization PAN India/Future Assignments',
#  'Leading activities related to PMO',
#  'Financial / T M Material projects',
#  'SLA Reporting',
#  'Compliance and Operations Audit for Production support',
#  'cloudwatch.',
#  'Windows Server',
#  'SQL Server',
#  'Teamwork',
#  'Documentation',
#  'Problem-solving',
#  'Azure',
#  'Cloud Computing',
#  'Tableau',
#  'Microstrategy',
#  'Excel',
#  'SQL',
#  'Data Warehousing',
#  'RPGILE. RPG/Free',
#  'I series',
#  'Job Scheduler',
#  'Gentran Premenos',
#  'Windows',
#  'Linux.',
#  'STS',
#  'Spring 3.X+',
#  'Global Team Management',
#  'Supply Chain Development',
#  'Program Management',
#  'Auditing',
#  'Carrier Management',
# ...

# %%
len(list(set(missed_skills)))
# Out:
# 263

# %%
import unicodedata
import shutil
def is_pua(c):
    return unicodedata.category(c)=='Co'
def contains_word(s, w):
    return (' ' + w + ' ') in (' ' + s + ' ')

# %%
len(glob.glob(r"/home/ptgml/Desktop/resumes_fractionable/*/*.pdf"))
# Out:
# 2506

# %%
number = 1
skill_count = []
for fname in glob.glob(r"/home/ptgml/Desktop/resumes_fractionable/*/*.pdf"):
    try:
        doc = fitz.open(fname)
        text = ""
        for page in doc:
            text = text + str(page.get_text())
                    
        print(fname)
        words
        temp_dict = {
            "fname" : fname,
            "skill_count" : len(list(set([word for word in missed_skills if " "+word+" " in text]))),
            "skills": list(set([word for word in missed_skills if " "+word+" " in text]))
        }
        skill_count.append(temp_dict)
#         if any(" "+word+ " " in text for word in missed_skills):
#             name = fname.split("/")[-1]
#             shutil.copyfile(fname, f"//home//ptgml//Desktop//resumes//{name}")
#             number += 1
    except:
        pass
# Out:
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Profile_Gurudutt_Raval.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/SanjayYadav.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Profile_Sasi_Nori.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Resume_CV_Yugank_Singh.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Profile_Dharmendra_Singh.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Scott_Yeager_-_Resume.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Converted%20%282%29.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Profile_Ashish_Shahane.pdf
# /home/ptgml/Desktop/resumes_fractionable/Oracle Apps (GL Finance Analyst)/Dice_Resume_CV_Raju_Bandam.pdf
# ...

# %%
def clean_txt(txt):
    text = "".join([char for char in txt if not is_pua(char)])
    text = text.replace("–", "-")
    text = re.sub(r'[^\w@+_.//,/:-]', ' ', text)
    text = " ".join(text.split())
    text = text.strip()
    text = " ".join(text.split())
    return text

# %%
for fname in glob.glob(r"/home/ptgml/Desktop/argilla_annotations/31_05_23/abnormal/*.pdf")[2:5]:
    doc = fitz.open(fname)
    text = ""
    for page in doc:
        text = text + str(page.get_text())
#     import pdb; pdb.set_trace();
    split_1 = ""
    for line in text.split("\n"):
        if len(split_1) <= len(text)/2:
            if line.strip()!= "":
                split_1 = split_1 + line.strip()
        else:
            break
#     import pdb; pdb.set_trace();
    split_2 = clean_txt(text[len(split_1):])
    split_1 = clean_txt(text[0:len(split_1)])
    records=[]
    doc_1 = nlp1(split_1)
    entities_1 = [(ent.label_, ent.start_char, ent.end_char) for ent in doc_1.ents]
    tokens_1 = [token.text for token in doc_1]
    records.append(
            rg.TokenClassificationRecord(
                text=split_1,
                tokens=tokens_1,
                prediction=entities_1,
                prediction_agent="resume_parser",
            )
        )
    rg.log(records=records, name="split_1_1")
    records=[]
    doc_2 = nlp1(split_2)
    entities_2 = [(ent.label_, ent.start_char, ent.end_char) for ent in doc_2.ents]
    tokens_2 = [token.text for token in doc_2]
    records.append(
            rg.TokenClassificationRecord(
                text=split_2,
                tokens=tokens_2,
                prediction=entities_2,
                prediction_agent="resume_parser",
            )
        )
    rg.log(records=records, name="split_1_2")
    records = tuple(records)
    
    print(fname)
    break
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1 records logged to http://localhost:6900/datasets/argilla/split_1_1
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1 records logged to http://localhost:6900/datasets/argilla/split_1_2
# /home/ptgml/Desktop/argilla_annotations/31_05_23/abnormal/SUPAPORN_SUKPREM_RESUME%20%281%29.docx.pdf

# %%
skill_count = sorted(skill_count, key=lambda k: k['skill_count'], reverse=True)

# %%
skill_count

# %%
import fitz
import glob
glob.glob(r"/home/ptgml/Desktop/resumes_fractionable/*/*.pdf")

# %%
nlp=spacy.load(r"/home/ptgml/latest_train/entire_resume_20230608-090016/model-best/")

# %%
def is_pua(c):
    return unicodedata.category(c) == 'Co'

# %%
### uploading resumes to argilla

# %%
resumes=[]
resume_count = 1
a = 1
b = 21
c = 1
name_num = 1
max_len = len(glob.glob(r"/home/ptgml/Desktop/argilla_annotations/08-06-23/*.pdf"))
print(max_len)
while a <= max_len and b <= max_len and name_num <= 6:
    candidates_list = ['ravi_','krishna_08']
    records = []
    for fname in glob.glob(r"/home/ptgml/Desktop/argilla_annotations/08-06-23/*.pdf")[a:b]:
        print(fname)
        try:
            doc=fitz.open(fname)
            text=" "
            for page in doc:
                text=text+str(page.get_text())
            text = "".join([char for char in text if not is_pua(char)])
            text = text.replace("–", "-")
            text = re.sub(r'[^\w@+_.//,/:-]', ' ', text)
            text = " ".join(text.split())
            text = text.strip()
            doc = nlp(text)
            entities = [(ent.label_, ent.start_char, ent.end_char) for ent in doc.ents]
            # Pre-tokenized input text
            tokens = [token.text for token in doc]
            records.append(
                    rg.TokenClassificationRecord(
                        text=text,
                        tokens=tokens,
                        prediction=entities,
                        prediction_agent="resume_parser",
                    )
                )
    #         check_file = Path(f"/home/praveen/Desktop/argilla annotations/26-04-23/can_{name_num}")
    #         print(check_file.is_file(), "-------------")
            print(os.path.join(os.getcwd(),"08-06-23",candidates_list[name_num]))
            if os.path.exists(os.path.join(os.getcwd(),"08-06-23",candidates_list[name_num])) == False:
                parent_dir = "/home/ptgml/Desktop/argilla_annotations/08-06-23/"
                new_dir = f"{candidates_list[name_num]}"
                path = os.path.join(parent_dir, new_dir)
                os.mkdir(path)
            shutil.copy(fname, f"/home/ptgml/Desktop/argilla_annotations/08-06-23/{candidates_list[name_num]}")
            os.remove(fname)
        except:
            pass
    rg.log(records=records, name=f"{candidates_list[name_num]}")
    a = a + 20
    b = b + 20 if b + 20 <= max_len else max_len
    name_num += 1
    print("-------------------------------------------------------")
#         print(fname)
#         print("i'm here")
#         doc=fitz.open(fname)
#         text=" "
#         for page in doc:
#             text=text+str(page.get_text())
#         text = "".join([char for char in text if not is_pua(char)])
#         text = text.replace("–", "-")
#         text = re.sub(r'[^\w@+_.//,/:-]', ' ', text)
#         text = " ".join(text.split())
#         text = text.strip()
#         print(text)
#         doc = nlp(text)
#         entities = [(ent.label_, ent.start_char, ent.end_char) for ent in doc.ents]
#         # Pre-tokenized input text
#         tokens = [token.text for token in doc]
#         records.append(
#                 rg.TokenClassificationRecord(
#                     text=text,
#                     tokens=tokens,
#                     prediction=entities,
#                     prediction_agent="resume_parser",
#                 )
#             )
#         resume_count += 1
#     rg.log(records=records, name=f"can_{name_num}")
#     name_num += 1 
#     break
    
#             try:
#                 print(f_name)
#                 a=convert(f_name)
#                 print(type(a))
#                 resumes.append(a)
#                 print(len(resumes))
#             except:
#                 pass
# resumes_text=os.linesep.join(resumes)
# f=open(r"C:\Users\ravit\OneDrive\Desktop\sri\resume>=50.txt",'a',encoding='utf-8')
# f.write(resumes_text)
# f.close()
# Out:
# 21
# /home/ptgml/Desktop/argilla_annotations/08-06-23/268297_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/271790_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/264087_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/267604_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/265081_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/271605_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/262789_9.0.pdf
# /home/ptgml/Desktop/argilla_annotations/08-06-23/krishna_08
# /home/ptgml/Desktop/argilla_annotations/08-06-23/266605_9.0.pdf
# ...

# %%
#downloading annotations into s3

# %%
import datetime

# %%
can_list=['praveen_07']
current_date = datetime.datetime.now()
resume_id = 1
s3 = boto3.client('s3',"ap-south-1",aws_access_key_id='AKIAZP5PPFU6ODPCFCPA',aws_secret_access_key='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')
for candidate in can_list:
    print(candidate)
    data_sets = rg.load(candidate)
    for data_set in data_sets:
        if dict(data_set)['annotation'] is not None:
            if len(dict(data_set)['annotation']) > 0:
                print(dict(data_set).keys())
                temp_data = []
                temp_ent = []
                experience_starts = []
                experience_ends = []
                education_starts = []
                education_ends = []
                personal_starts =[]
                personal_ends = []
                exp_entities_lst = []
                experience_lst = []
                edu_entities_lst = []
                education_lst = []
                personal_entities_lst = []
                personal_lst = []
                temp_data.append(dict(data_set)['text'])
                for ent in dict(data_set)['annotation']:
                    print(ent[0], ent[1], ent[2])
                    if ent[0] in ["COMPANY","COMPANY_LOC","WORKING_DATES","PROJECTS","SKILLS","DESGINATION"]:
                        experience_starts.append(ent[1])
                        experience_ends.append(ent[2])
                    if ent[0] in ["AWARDS","CERTIFICATIONS","EDUCATIONAL_INSTITUTION","HIGHER_EDUCATION","PASSOUTYEAR"]:
                        education_starts.append(ent[1])
                        education_ends.append(ent[2])
                    if ent[0] in ["EMAIL","GITHUB_URL","LINKEDIN_URL","NAME","PERSON_ADDRESS", "PHONE_NO", "SUMMARY", "TOTAL_EXP"]:
                        personal_starts.append(ent[1])
                        personal_ends.append(ent[2])
                    temp_ent.append([ent[1],ent[2],ent[0]])
                
                if len(experience_starts) >0 and len(experience_ends) > 0:
                    exp_start_span = min(experience_starts)
                    exp_ends_span = max(experience_ends)
                    exp_data = dict(data_set)['text'][exp_start_span:exp_ends_span]
                
                    for ety in dict(data_set)['annotation']:
                        ety = list(ety)
                        if ety[0] in ["COMPANY","COMPANY_LOC","WORKING_DATES","PROJECTS","SKILLS","DESGINATION"]:
                            ety[1] = ety[1]-exp_start_span
                            ety[2] = ety[2] -exp_start_span
                            exp_entities_lst.append((ety[1],ety[2],ety[0]))
                    #print("success")

                    experience_lst.append(exp_data)
                    exp_new_dict = {'entities': exp_entities_lst}
                    experience_lst.append(exp_new_dict)
                    resume_section = "experience_details_section"
                    s3.put_object(
                         Body=json.dumps(experience_lst),
                         Bucket='fractionable',
                         Key=f"val_argilla1/{resume_section}/{current_date}/resume_{resume_id}"
                    )
            
                if len(education_starts) >0 and len(education_ends) > 0:
                    edu_start_span = min(education_starts)
                    edu_ends_span = max(education_ends)
                    edu_data = dict(data_set)['text'][edu_start_span:edu_ends_span]
                    for ety in dict(data_set)['annotation']:
                        ety = list(ety)
                        if ety[0] in ["AWARDS","CERTIFICATIONS","EDUCATIONAL_INSTITUTION","HIGHER_EDUCATION","PASSOUTYEAR"]:
                            ety[1] = ety[1]-edu_start_span
                            ety[2] = ety[2] -edu_start_span
                            edu_entities_lst.append((ety[1],ety[2],ety[0]))

                    education_lst.append(edu_data)
                    edu_new_dict = {'entities': edu_entities_lst}
                    education_lst.append(edu_new_dict)
                    resume_section = "education_details_section"
                    s3.put_object(
                         Body=json.dumps(education_lst),
                         Bucket='fractionable',
                         Key=f"val_argilla1/{resume_section}/{current_date}/resume_{resume_id}"
                    )
                if len(personal_starts) >0 and len(personal_ends) > 0:
                    per_start_span = min(personal_starts)
                    per_ends_span = max(personal_ends)
                    per_data = dict(data_set)['text'][per_start_span:per_ends_span]
                    for ety in dict(data_set)['annotation']:
                        ety = list(ety)
                        if ety[0] in ["EMAIL","GITHUB_URL","LINKEDIN_URL","NAME","PERSON_ADDRESS", "PHONE_NO", "SUMMARY", "TOTAL_EXP"]:
                            ety[1] = ety[1]-per_start_span
                            ety[2] = ety[2] -per_start_span
                            personal_entities_lst.append((ety[1],ety[2],ety[0]))

                    personal_lst.append(per_data)
                    per_new_dict = {'entities': personal_entities_lst}
                    personal_lst.append(per_new_dict)
                    resume_section = "personal_details_section"
                    s3.put_object(
                         Body=json.dumps(personal_lst),
                         Bucket='fractionable',
                         Key=f"val_argilla1/{resume_section}/{current_date}/resume_{resume_id}"
                    )
                temp_dict = {
                    "entities":temp_ent
                }
                temp_data.append(temp_dict)
                json_str = json.dumps(temp_data)
                resume_section = "entire_resume"
                s3 = boto3.client('s3',"ap-south-1",aws_access_key_id='AKIAZP5PPFU6ODPCFCPA',aws_secret_access_key='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')
                s3.put_object(
                     Body=json.dumps(temp_data),
                     Bucket='fractionable',
                     Key=f"val_argilla1/{resume_section}/{current_date}/resume_{resume_id}"
                )
                resume_id += 1
                #break
# Out:
# praveen_07
# dict_keys(['text', 'tokens', 'prediction', 'prediction_agent', 'annotation', 'annotation_agent', 'id', 'metadata', 'status', 'event_timestamp', 'metrics', 'search_keywords'])
# PERSON_ADDRESS 0 11
# PHONE_NO 12 24
# EMAIL 25 50
# LINKEDIN_URL 51 80
# NAME 81 94
# DESGINATION 1758 1808
# COMPANY 1809 1833
# COMPANY_LOC 1835 1846
# WORKING_DATES 1847 1858
# DESGINATION 2838 2853
# COMPANY 2854 2874
# COMPANY_LOC 2876 2887
# WORKING_DATES 2888 2899
# DESGINATION 3777 3794
# COMPANY 3795 3804
# COMPANY_LOC 3806 3817
# WORKING_DATES 3818 3829
# DESGINATION 5599 5619
# COMPANY 5620 5634
# COMPANY_LOC 5636 5647
# WORKING_DATES 5648 5659
# DESGINATION 6369 6391
# COMPANY 6392 6414
# COMPANY_LOC 6416 6428
# WORKING_DATES 6429 6440
# DESGINATION 7543 7580
# COMPANY 7592 7598
# COMPANY_LOC 7599 7610
# WORKING_DATES 7611 7622
# DESGINATION 7623 7653
# COMPANY 7681 7690
# WORKING_DATES 7709 7720
# DESGINATION 7721 7766
# COMPANY 7767 7774
# WORKING_DATES 7793 7804
# ...
